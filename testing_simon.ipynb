# %%
from ForestCoverDataset import ForestCoverDataset
import matplotlib.pyplot as plt
import numpy as np
from utils import reverse_one_hot

train_dataset = ForestCoverDataset(one_hot_masks=False)
print(train_dataset[100][0].shape)
print(np.min(train_dataset[0][0]))
print(np.max(train_dataset[0][0]))
plt.imshow(train_dataset[0][0].transpose(1, 2, 0))
# Out:
# (3, 512, 512)
# 0.0005
# 1.0

# %%
print(train_dataset[100][1].shape)
print(np.min(train_dataset[0][1]))
print(np.max(train_dataset[0][1]))
plt.imshow(np.squeeze(train_dataset[0][1]))
# Out:
# (1, 512, 512)
# 0.0
# 1.0

# %%
train_dataset = ForestCoverDataset(one_hot_masks=True)
print(train_dataset[100][1].shape)
plt.imshow(reverse_one_hot(train_dataset[0][1].transpose(1, 2, 0)))
# Out:
# (2, 512, 512)

# %%
train_dataset = ForestCoverDataset(NIR=True)
print(train_dataset[100][0].shape)
plt.imshow(train_dataset[0][0][:3].transpose(1, 2, 0))
# Out:
# (4, 512, 512)
